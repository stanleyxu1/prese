# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\stanx\Downloads\1976-2020-president.csv")
data = data.drop(columns=['state_fips', 'state_cen', 'state_ic', 'state_po', 'version'])
data = data.where(data['office'] == 'US PRESIDENT')
data
# Out:
#       year    state        office                candidate  \
# 0     1976  ALABAMA  US PRESIDENT            CARTER, JIMMY
# 1     1976  ALABAMA  US PRESIDENT             FORD, GERALD
# 2     1976  ALABAMA  US PRESIDENT           MADDOX, LESTER
# 3     1976  ALABAMA  US PRESIDENT  BUBAR, BENJAMIN ""BEN""
# 4     1976  ALABAMA  US PRESIDENT                HALL, GUS
# ...    ...      ...           ...                      ...
# 4282  2020  WYOMING  US PRESIDENT            JORGENSEN, JO
# 4283  2020  WYOMING  US PRESIDENT            PIERCE, BROCK
# 4284  2020  WYOMING  US PRESIDENT                      NaN
# 4285  2020  WYOMING  US PRESIDENT                OVERVOTES
# 4286  2020  WYOMING  US PRESIDENT               UNDERVOTES
#
#                   party_detailed writein  candidatevotes  totalvotes  notes  \
# 0                       DEMOCRAT   False          659170     1182850    NaN
# 1                     REPUBLICAN   False          504070     1182850    NaN
# ...

# %%
temp = data.groupby(['year', 'state']).head(1)
temp = temp.drop(columns=['writein'])
temp.head(500)
# Out:
#       year           state        office         candidate party_detailed  \
# 0     1976         ALABAMA  US PRESIDENT     CARTER, JIMMY       DEMOCRAT
# 7     1976          ALASKA  US PRESIDENT      FORD, GERALD     REPUBLICAN
# 11    1976         ARIZONA  US PRESIDENT      FORD, GERALD     REPUBLICAN
# 19    1976        ARKANSAS  US PRESIDENT     CARTER, JIMMY       DEMOCRAT
# 23    1976      CALIFORNIA  US PRESIDENT      FORD, GERALD     REPUBLICAN
# ...    ...             ...           ...               ...            ...
# 3310  2012        OKLAHOMA  US PRESIDENT      ROMNEY, MITT     REPUBLICAN
# 3312  2012          OREGON  US PRESIDENT  OBAMA, BARACK H.       DEMOCRAT
# 3319  2012    PENNSYLVANIA  US PRESIDENT  OBAMA, BARACK H.       DEMOCRAT
# 3323  2012    RHODE ISLAND  US PRESIDENT  OBAMA, BARACK H.       DEMOCRAT
# 3331  2012  SOUTH CAROLINA  US PRESIDENT      ROMNEY, MITT     REPUBLICAN
#
#       candidatevotes  totalvotes  notes party_simplified
# ...

# %%
temp1 = temp
temp1.groupby('year')
same = temp1['candidate'] == temp1['candidate'][0]
temp1['wonAll'] = same
temp1
# Out:
#       year          state        office            candidate party_detailed  \
# 0     1976        ALABAMA  US PRESIDENT        CARTER, JIMMY       DEMOCRAT
# 7     1976         ALASKA  US PRESIDENT         FORD, GERALD     REPUBLICAN
# 11    1976        ARIZONA  US PRESIDENT         FORD, GERALD     REPUBLICAN
# 19    1976       ARKANSAS  US PRESIDENT        CARTER, JIMMY       DEMOCRAT
# 23    1976     CALIFORNIA  US PRESIDENT         FORD, GERALD     REPUBLICAN
# ...    ...            ...           ...                  ...            ...
# 4252  2020       VIRGINIA  US PRESIDENT  BIDEN, JOSEPH R. JR       DEMOCRAT
# 4256  2020     WASHINGTON  US PRESIDENT  BIDEN, JOSEPH R. JR       DEMOCRAT
# 4263  2020  WEST VIRGINIA  US PRESIDENT  BIDEN, JOSEPH R. JR       DEMOCRAT
# 4267  2020      WISCONSIN  US PRESIDENT  BIDEN, JOSEPH R. JR       DEMOCRAT
# 4280  2020        WYOMING  US PRESIDENT  BIDEN, JOSEPH R. JR       DEMOCRAT
#
# ...
